# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiteja2812/LGM-TASK-2/blob/main/Lets_Grow_More_Task_2(Image_to_Sketch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LETS GROW MORE(VIP) JANUARY 2022**

# %% [markdown]
# # **IMAGE TO PENCIL SKETCH WITH PYTHON**

# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # **LOADING IMAGE**

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-78d40542-e8b4-417a-9536-7be6de343abb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78d40542-e8b4-417a-9536-7be6de343abb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lion.jpg to lion (1).jpg

# %%
pic = cv2.imread("lion (1).jpg")

# %%
pic
# Out:
# array([[[ 90,  91,  87],
#         [ 92,  93,  89],
#         [ 92,  96,  91],
#         ...,
#         [ 78,  75,  71],
#         [ 80,  77,  73],
#         [ 82,  79,  75]],
#
#        [[ 88,  89,  85],
#         [ 89,  90,  86],
#         [ 91,  92,  88],
#         ...,
#         [ 79,  76,  72],
#         [ 81,  78,  74],
#         [ 83,  80,  76]],
#
#        [[ 86,  85,  81],
#         [ 85,  86,  82],
#         [ 87,  88,  84],
#         ...,
#         [ 80,  77,  73],
#         [ 82,  79,  75],
#         [ 84,  81,  77]],
#
#        ...,
#
#        [[135, 172, 156],
#         [146, 183, 167],
#         [158, 191, 176],
#         ...,
#         [ 62,  85,  71],
#         [ 68,  91,  77],
#         [ 85, 108,  94]],
#
#        [[134, 171, 155],
#         [142, 179, 163],
#         [147, 180, 165],
#         ...,
#         [ 67,  90,  76],
#         [ 70,  93,  79],
#         [ 86, 109,  95]],
#
#        [[134, 171, 155],
#         [138, 175, 159],
#         [140, 173, 158],
#         ...,
#         [ 79,  99,  86],
#         [ 75,  95,  82],
#         [ 85, 105,  92]]], dtype=uint8)

# %% [markdown]
# # **ORGINAL IMAGE**

# %%
plt.imshow(pic[:,:,::-1])
plt.axis(False)
plt.show()

# %%
plt.imshow(pic)
plt.axis(False)
plt.show()

# %%
RGB_pic = cv2.cvtColor(pic, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_pic)
plt.axis(False)
plt.show()

# %%
grey_pic =cv2.cvtColor(pic, cv2.COLOR_BGR2GRAY)

# %%
invert_pic =cv2.bitwise_not(grey_pic)

# %%
blur_pic =cv2.GaussianBlur(invert_pic, (111,111),0)

# %%
invblur_pic =cv2.bitwise_not(blur_pic)

# %%
sketch_pic = cv2.divide(grey_pic, invblur_pic, scale=256.0)

# %% [markdown]
# # **PENCIL SKETCH**

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Orginal', size=18)
plt.imshow(RGB_pic)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Pencil Sketch', size=18)
rgb_sketch=cv2.cvtColor(sketch_pic, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()
